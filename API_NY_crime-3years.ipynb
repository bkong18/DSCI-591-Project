# %% [markdown]
# # Code for NY crime data processing
# # 1. API interface
# Last modified: Oct. 1, 2021

# %% [markdown]
# ## 1.1 Get data by selected date

# %% [markdown]
# ### Sample: Get year 2018-2020 data

# %%
# make sure to install these packages before running:
# pip install sodapy
import pandas as pd
from sodapy import Socrata

# Access NY Open Data API
client = Socrata("data.cityofnewyork.us",
                  "SS1FLB8GKDDdNcRMJwXFNS0Wr",
                  username="mk3268@drexel.edu",
                  password="Mact98xz!")

results = client.get("qgea-i56i", limit=1500000,  
    where="cmplnt_fr_dt >= '2018-01-01' and cmplnt_fr_dt <= '2020-12-31'")

# Convert to pandas DataFrame
results_year_2018 = pd.DataFrame.from_records(results)
results_year_2018
# Out:
#         cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm  \
# 0        947161850  2018-01-01T00:00:00.000     08:00:00
# 1        963870686  2018-01-01T00:00:00.000     00:01:00
# 2        923975917  2018-01-01T00:00:00.000     07:00:00
# 3        553803536  2018-01-01T00:00:00.000     00:01:00
# 4        994797810  2018-01-01T00:00:00.000     12:00:00
# ...            ...                      ...          ...
# 1324334  165691435  2020-12-31T00:00:00.000     20:40:00
# 1324335  408014308  2020-12-31T00:00:00.000     15:00:00
# 1324336  152189917  2020-12-31T00:00:00.000     21:30:00
# 1324337  819066061  2020-12-31T00:00:00.000     20:22:00
# 1324338  675684827  2020-12-31T00:00:00.000     00:42:00
#
#                     cmplnt_to_dt cmplnt_to_tm addr_pct_cd  \
# 0        2019-07-31T00:00:00.000     08:00:00          10
# 1        2019-10-10T00:00:00.000     23:59:00         103
# 2        2019-11-30T00:00:00.000     14:00:00         112
# ...

# %%
### Save to CSV file (write to a file)
results_year_2018.to_csv("ny_2018-2020.csv", index = False)

# %% [markdown]
# ## 1.2 Attribute selection

# %%
# make sure to install these packages before running:
# pip install sodapy
import pandas as pd
from sodapy import Socrata

# Access NY Open Data API
client = Socrata("data.cityofnewyork.us",
                  "SS1FLB8GKDDdNcRMJwXFNS0Wr",
                  username="mk3268@drexel.edu",
                  password="Mact98xz!")

results = client.get("qgea-i56i", limit=1500000,  
    where="cmplnt_fr_dt >= '2018-01-01' and cmplnt_fr_dt <= '2018-01-07'",
    select = "cmplnt_num, cmplnt_fr_dt, cmplnt_fr_tm, law_cat_cd, ofns_desc, \
    loc_of_occur_desc, latitude, longitude, susp_age_group, susp_race, susp_sex, \
    vic_age_group, vic_race, vic_sex")
# Convert to pandas DataFrame
results_selct = pd.DataFrame.from_records(results)
results_selct
# Out:
#      cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm   law_cat_cd  \
# 0     947161850  2018-01-01T00:00:00.000     08:00:00       FELONY
# 1     963870686  2018-01-01T00:00:00.000     00:01:00       FELONY
# 2     923975917  2018-01-01T00:00:00.000     07:00:00       FELONY
# 3     553803536  2018-01-01T00:00:00.000     00:01:00  MISDEMEANOR
# 4     994797810  2018-01-01T00:00:00.000     12:00:00  MISDEMEANOR
# ...         ...                      ...          ...          ...
# 8046  774805854  2018-01-07T00:00:00.000     19:10:00       FELONY
# 8047  354981956  2018-01-07T00:00:00.000     18:00:00  MISDEMEANOR
# 8048  548498111  2018-01-07T00:00:00.000     03:00:00  MISDEMEANOR
# 8049  330883634  2018-01-07T00:00:00.000     21:50:00       FELONY
# 8050  480203632  2018-01-07T00:00:00.000     21:40:00       FELONY
#
#                            ofns_desc loc_of_occur_desc            latitude  \
# 0                      GRAND LARCENY            INSIDE   40.74283378800004
# ...

# %%
# make sure to install these packages before running:
# pip install sodapy
import pandas as pd
from sodapy import Socrata

# Access NY Open Data API
client = Socrata("data.cityofnewyork.us",
                  "SS1FLB8GKDDdNcRMJwXFNS0Wr",
                  username="mk3268@drexel.edu",
                  password="Mact98xz!")

results = client.get("qgea-i56i", limit=1000000,  
    where="cmplnt_fr_dt >= '2017-01-01' and cmplnt_fr_dt <= '2020-12-31'")

# Convert to pandas DataFrame
results_year_2018 = pd.DataFrame.from_records(results)
results_year_2018
# Out:
#        cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm  \
# 0       216044876  2017-01-01T00:00:00.000     11:00:00
# 1       112025807  2017-01-01T00:00:00.000     09:00:00
# 2       669902330  2017-01-01T00:00:00.000     00:01:00
# 3       579530319  2017-01-01T00:00:00.000     00:00:00
# 4       232211816  2017-01-01T00:00:00.000     00:01:00
# ...           ...                      ...          ...
# 999995  171093637  2019-03-02T00:00:00.000     01:30:00
# 999996  626329761  2019-03-02T00:00:00.000     21:28:00
# 999997  280309300  2019-03-02T00:00:00.000     11:53:00
# 999998  812193412  2019-03-02T00:00:00.000     07:39:00
# 999999  314149792  2019-03-02T00:00:00.000     14:30:00
#
#                    cmplnt_to_dt cmplnt_to_tm addr_pct_cd  \
# 0       2018-08-20T00:00:00.000     12:00:00         109
# 1       2019-09-01T00:00:00.000     09:00:00          13
# 2       2017-12-31T00:00:00.000     23:59:00         114
# 3       2019-12-01T00:00:00.000     00:00:00          71
# ...
